# %%
import pandas as pd
df = pd.read_csv('COVID_BPA.csv')
df
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 0       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 2       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 3       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 4       09/24/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# ...            ...         ...         ...       ...     ...    ...
# 620995  09/24/2023  05/01/2023  05/31/2023  By Month  2023.0    5.0
# 620996  09/24/2023  06/01/2023  06/30/2023  By Month  2023.0    6.0
# 620997  09/24/2023  07/01/2023  07/31/2023  By Month  2023.0    7.0
# 620998  09/24/2023  08/01/2023  08/31/2023  By Month  2023.0    8.0
# 620999  09/24/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#                 State       Condition Group                Condition  \
# 0       United States  Respiratory diseases  Influenza and pneumonia
# ...

# %%
df1 = df[df['Group'] == 'By Month']

# %%
df1
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 62100   09/24/2023  01/01/2020  01/31/2020  By Month  2020.0    1.0
# 62101   09/24/2023  02/01/2020  02/29/2020  By Month  2020.0    2.0
# 62102   09/24/2023  03/01/2020  03/31/2020  By Month  2020.0    3.0
# 62103   09/24/2023  04/01/2020  04/30/2020  By Month  2020.0    4.0
# 62104   09/24/2023  05/01/2020  05/31/2020  By Month  2020.0    5.0
# ...            ...         ...         ...       ...     ...    ...
# 620995  09/24/2023  05/01/2023  05/31/2023  By Month  2023.0    5.0
# 620996  09/24/2023  06/01/2023  06/30/2023  By Month  2023.0    6.0
# 620997  09/24/2023  07/01/2023  07/31/2023  By Month  2023.0    7.0
# 620998  09/24/2023  08/01/2023  08/31/2023  By Month  2023.0    8.0
# 620999  09/24/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#                 State       Condition Group                Condition  \
# 62100   United States  Respiratory diseases  Influenza and pneumonia
# ...

# %%
df1.drop('ICD10_codes',axis = 1,inplace = True)
# Out:
# C:\Users\venka\AppData\Local\Temp\ipykernel_13372\922475127.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('ICD10_codes',axis = 1,inplace = True)

# %%
df1.drop('Flag',axis = 1,inplace = True)
# Out:
# C:\Users\venka\AppData\Local\Temp\ipykernel_13372\2652081250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('Flag',axis = 1,inplace = True)

# %%
df1
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 62100   09/24/2023  01/01/2020  01/31/2020  By Month  2020.0    1.0
# 62101   09/24/2023  02/01/2020  02/29/2020  By Month  2020.0    2.0
# 62102   09/24/2023  03/01/2020  03/31/2020  By Month  2020.0    3.0
# 62103   09/24/2023  04/01/2020  04/30/2020  By Month  2020.0    4.0
# 62104   09/24/2023  05/01/2020  05/31/2020  By Month  2020.0    5.0
# ...            ...         ...         ...       ...     ...    ...
# 620995  09/24/2023  05/01/2023  05/31/2023  By Month  2023.0    5.0
# 620996  09/24/2023  06/01/2023  06/30/2023  By Month  2023.0    6.0
# 620997  09/24/2023  07/01/2023  07/31/2023  By Month  2023.0    7.0
# 620998  09/24/2023  08/01/2023  08/31/2023  By Month  2023.0    8.0
# 620999  09/24/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#                 State       Condition Group                Condition  \
# 62100   United States  Respiratory diseases  Influenza and pneumonia
# ...

# %%
#Check the data types
display(df1.dtypes)
# Out:
# Data As Of             object
# Start Date             object
# End Date               object
# Group                  object
# Year                  float64
# Month                 float64
# State                  object
# Condition Group        object
# Condition              object
# Age Group              object
# COVID-19 Deaths       float64
# Number of Mentions    float64
# dtype: object

# %%
#Check for missing values
missing_values = df1.isnull().sum()
display(missing_values)
# Out:
# Data As Of                 0
# Start Date                 0
# End Date                   0
# Group                      0
# Year                       0
# Month                      0
# State                      0
# Condition Group            0
# Condition                  0
# Age Group                  0
# COVID-19 Deaths       170400
# Number of Mentions    165180
# dtype: int64

# %%
#Summary statistics
summary_stats = df.describe()
display(summary_stats)
# Out:
#                 Year          Month  COVID-19 Deaths  Number of Mentions
# count  608580.000000  558900.000000     4.375510e+05        4.434230e+05
# mean     2021.408163       6.200000     1.201179e+02        1.293348e+02
# std         1.086436       3.350625     2.980201e+03        3.203936e+03
# min      2020.000000       1.000000     0.000000e+00        0.000000e+00
# 25%      2020.000000       3.000000     0.000000e+00        0.000000e+00
# 50%      2021.000000       6.000000     0.000000e+00        0.000000e+00
# 75%      2022.000000       9.000000     1.800000e+01        1.900000e+01
# max      2023.000000      12.000000     1.146242e+06        1.146242e+06

# %% [markdown]
# For covid 19 deaths and number of mentions column missing value we will replace missing values with mean

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
df[['COVID-19 Deaths', 'Number of Mentions']].plot(kind='bar')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


condition_deaths = df.groupby('Condition Group')['COVID-19 Deaths'].sum()

# Plot a bar plot for 'condition' vs 'no of deaths'
plt.figure(figsize=(10, 6))
condition_deaths.plot(kind='bar')
plt.xlabel('Condition')
plt.ylabel('Total Number of Deaths')
plt.title('Total Number of Deaths by Condition')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %%
import seaborn as sns

heatmap_data = df.pivot_table(index='State', values='COVID-19 Deaths', aggfunc='sum')

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, fmt='g', cmap='YlGnBu')
plt.title('Number of Deaths by State')
plt.xlabel('Number of Deaths')
plt.ylabel('State')
plt.show()

# %%
age_deaths = df.groupby('Age Group')['COVID-19 Deaths'].sum()

# Plot a bar plot for 'condition' vs 'no of deaths'
plt.figure(figsize=(10, 6))
age_deaths.plot(kind='bar')
plt.xlabel('age')
plt.ylabel('Total Number of Deaths')
plt.title('Total Number of Deaths by age')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %%
age_cases = df.groupby('Age Group')['Number of Mentions'].sum()

# Plot a bar plot for 'condition' vs 'no of cases'
plt.figure(figsize=(10, 6))
age_cases.plot(kind='bar')
plt.xlabel('age')
plt.ylabel('Total Number of cases')
plt.title('Total Number of cases by age')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()
